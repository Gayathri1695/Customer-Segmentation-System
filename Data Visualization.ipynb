# %%
import pandas as pd
import numpy as np


data={


    
    "Customer_ID": [
        101, 102, 103, 104, 105, 
        106, 107, 108, 109, 110,
        111, 112, 113, 114, 115,
        116, 117, 118, 119, 120
    ],

    "Age": [
        22, 35, 28, 45, 52, 24, 24, 31, 40, 55, 
        38, 29, 48, 26, 36, 42, 30, 33, 50, 25
    ],

    "Annual_Income": [
        25000, 60000, 40000, 90000, 75000,
        30000, 30000, 50000,85000, 95000, 
        35000, 65000, 45000,80000, 28000,
        58000, 72000, 42000, 55000, 70000
    ],

    "Spending_Score": [
        85, 60, 75, 35, 25, 
        90, 90, 70, 45, 20,
        80, 55, 78, 30, 88, 
        62, 40, 72, 58, 35
    ],

   "Annual_Income": [
        18, 12, 15, 6, 4, 
        20, 20, 14, 8, 3,
        17, 11, 16, 5, 19, 
        13, 7, 15, 10, 6
    ],

    "Total_Spending": [
        45000, 38000, 42000, 25000, 18000, 
        52000, 52000, 40000,30000, 12000, 
        47000, 35000, 43000, 20000, 50000,
        39000, 27000, 41000, 34000, 23000
    ],

    "Website_Visits": [
        25, 18, 22, 10, 8, 
        30, 30, 21, 14, 6,
        27, 17, 24, 9, 29, 
        19, 12, 23, 16, 11
    ],

    "Customer_Visits": [
        12, 8, 10, 5, 3, 
        15, 15, 9, 6, 2,
        13, 7, 11, 4, 14, 
        9, 5, 10, 7, 4
    ],

    "Product_Interactions": [
        35, 24, 30, 15, 10, 
        42, 42, 28, 18, 8,
        38, 22, 33, 12, 40, 
        26, 16, 31, 21, 14
    ],

    "Preferred_Category": [
        "Electronics", "Clothing", "Groceries", "Electronics", "Furniture",
        "Clothing", "Clothing", "Electronics", "Groceries", "Furniture",
        "Electronics", "Clothing", "Groceries", "Furniture", "Electronics",
        "Clothing", "Furniture", "Groceries", "Electronics", "Clothing"
    ],

    "Membership_Type": [
        "Premium", "Regular", "Regular", "Premium", "Regular",
        "Premium", "Premium", "Regular", "Premium", "Basic",
        "Premium", "Regular", "Premium", "Basic", "Premium",
        "Regular", "Premium", "Regular", "Regular", "Basic"
    ],

    "Customer_Satisfaction": [
        9, 8, 8, 7, 6, 
        10, 10, 8, 7, 5,
        9, 7, 9, 5, 10, 
        8, 7, 9, 8, 6
    ]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Customer_ID  Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0           101   22          25000              85                  18
# 1           102   35          60000              60                  12
# 2           103   28          40000              75                  15
# 3           104   45          90000              35                   6
# 4           105   52          75000              25                   4
# 5           106   24          30000              90                  20
# 6           107   24          30000              90                  20
# 7           108   31          50000              70                  14
# 8           109   40          85000              45                   8
# 9           110   55          95000              20                   3
# 10          111   38          35000              80                  17
# 11          112   29          65000              55                  11
# ...

# %%
#  Histogram

import matplotlib.pyplot as plt
plt.hist(df["Customer_Satisfaction"], bins=10)
plt.title("Customer Satisfaction")
plt.xlabel("Satisfaction Level")
plt.ylabel("Purchase_Frequency")
plt.show()

# %%
# Box Plot
print("\n\n")
plt.boxplot(df["Website_Visits"])
plt.title("Box Plot of Website Visits")
plt.ylabel("Website Visits")
plt.show()

# %%
#bar chart

plt.bar(df["Age"], df["Spending_Score"])
plt.title("Spending Score by Age")
plt.xlabel("Age")
plt.ylabel("Spending Score")
plt.show()

# %%
# Scatter Plot
plt.scatter(df["Annual_Income"], df["Annual_Income"])
plt.title("Quantity and Sales")
plt.xlabel("Quantity")
plt.ylabel("Sales")
plt.show()

# %%
#pie chart

plt.pie(df["Customer_Visits"],autopct='%1.1f%%')
plt.title("Income and spending Score")
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.show()

# %%
plt.plot(df["Annual_Income"])
plt.title("Income and spending Score")
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.show()

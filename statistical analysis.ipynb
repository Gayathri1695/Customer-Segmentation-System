# %%
import pandas as pd
import numpy as np

data={


    
    "Customer_ID": [
        101, 102, 103, 104, 105, 
        106, 107, 108, 109, 110,
        111, 112, 113, 114, 115,
        116, 117, 118, 119, 120
    ],

    "Age": [
        22, 35, 28, 45, 52, 24, 24, 31, 40, 55, 
        38, 29, 48, 26, 36, 42, 30, 33, 50, 25
    ],

    "Annual_Income": [
        25000, 60000, 40000, 90000, 75000,
        30000, 30000, 50000,85000, 95000, 
        35000, 65000, 45000,80000, 28000,
        58000, 72000, 42000, 55000, 70000
    ],

    "Spending_Score": [
        85, 60, 75, 35, 25, 
        90, 90, 70, 45, 20,
        80, 55, 78, 30, 88, 
        62, 40, 72, 58, 35
    ],

    "Purchase_Frequency": [
        18, 12, 15, 6, 4, 
        20, 20, 14, 8, 3,
        17, 11, 16, 5, 19, 
        13, 7, 15, 10, 6
    ],

    "Total_Spending": [
        45000, 38000, 42000, 25000, 18000, 
        52000, 52000, 40000,30000, 12000, 
        47000, 35000, 43000, 20000, 50000,
        39000, 27000, 41000, 34000, 23000
    ],

    "Website_Visits": [
        25, 18, 22, 10, 8, 
        30, 30, 21, 14, 6,
        27, 17, 24, 9, 29, 
        19, 12, 23, 16, 11
    ],

    "Customer_Visits": [
        12, 8, 10, 5, 3, 
        15, 15, 9, 6, 2,
        13, 7, 11, 4, 14, 
        9, 5, 10, 7, 4
    ],

    "Product_Interactions": [
        35, 24, 30, 15, 10, 
        42, 42, 28, 18, 8,
        38, 22, 33, 12, 40, 
        26, 16, 31, 21, 14
    ],

    "Preferred_Category": [
        "Electronics", "Clothing", "Groceries", "Electronics", "Furniture",
        "Clothing", "Clothing", "Electronics", "Groceries", "Furniture",
        "Electronics", "Clothing", "Groceries", "Furniture", "Electronics",
        "Clothing", "Furniture", "Groceries", "Electronics", "Clothing"
    ],

    "Membership_Type": [
        "Premium", "Regular", "Regular", "Premium", "Regular",
        "Premium", "Premium", "Regular", "Premium", "Basic",
        "Premium", "Regular", "Premium", "Basic", "Premium",
        "Regular", "Premium", "Regular", "Regular", "Basic"
    ],

    "Customer_Satisfaction": [
        9, 8, 8, 7, 6, 
        10, 10, 8, 7, 5,
        9, 7, 9, 5, 10, 
        8, 7, 9, 8, 6
    ]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Customer_ID  Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0           101   22          25000              85                  18
# 1           102   35          60000              60                  12
# 2           103   28          40000              75                  15
# 3           104   45          90000              35                   6
# 4           105   52          75000              25                   4
# 5           106   24          30000              90                  20
# 6           107   24          30000              90                  20
# 7           108   31          50000              70                  14
# 8           109   40          85000              45                   8
# 9           110   55          95000              20                   3
# 10          111   38          35000              80                  17
# 11          112   29          65000              55                  11
# 12          113   48          45000              78                  16
# 13          114   26          80000              30                   5
# 14          115   36          28000              88                  19
# 15          116   42          58000              62                  13
# 16          117   30          72000              40                   7
# 17          118   33          42000              72                  15
# 18          119   50          55000              58                  10
# 19          120   25          70000              35                   6
#
#     Total_Spending  Website_Visits  Customer_Visits  Product_Interactions  \
# 0            45000              25               12                    35
# 1            38000              18                8                    24
# 2            42000              22               10                    30
# 3            25000              10                5                    15
# 4            18000               8                3                    10
# 5            52000              30               15                    42
# 6            52000              30               15                    42
# 7            40000              21                9                    28
# 8            30000              14                6                    18
# 9            12000               6                2                     8
# 10           47000              27               13                    38
# 11           35000              17                7                    22
# 12           43000              24               11                    33
# 13           20000               9                4                    12
# 14           50000              29               14                    40
# 15           39000              19                9                    26
# 16           27000              12                5                    16
# 17           41000              23               10                    31
# 18           34000              16                7                    21
# 19           23000              11                4                    14
#
#    Preferred_Category Membership_Type  Customer_Satisfaction
# 0         Electronics         Premium                      9
# 1            Clothing         Regular                      8
# 2           Groceries         Regular                      8
# 3         Electronics         Premium                      7
# 4           Furniture         Regular                      6
# 5            Clothing         Premium                     10
# 6            Clothing         Premium                     10
# 7         Electronics         Regular                      8
# 8           Groceries         Premium                      7
# 9           Furniture           Basic                      5
# 10        Electronics         Premium                      9
# 11           Clothing         Regular                      7
# 12          Groceries         Premium                      9
# 13          Furniture           Basic                      5
# 14        Electronics         Premium                     10
# 15           Clothing         Regular                      8
# 16          Furniture         Premium                      7
# 17          Groceries         Regular                      9
# 18        Electronics         Regular                      8
# 19           Clothing           Basic                      6

# %%
print("Mean:", df["Total_Spending"].mean())
# Out:
# Mean: 35650.0

# %%
print("Annual_Income(median):", df["Annual_Income"].median())
# Out:
# Annual_Income(median): 56500.0

# %%
print(df["Spending_Score"].mode())
# Out:
# 0    35
# 1    90
# Name: Spending_Score, dtype: int64

# %%
print("Customer_Visits(max):",df["Customer_Visits"].max())
# Out:
# Customer_Visits(max): 15

# %%
print("Annual_Income(min):", df["Annual_Income"].min())
# Out:
# Annual_Income(min): 25000

# %%
print("Product_Interactions(variance):", df["Product_Interactions"].var())
# Out:
# Product_Interactions(variance): 119.25

# %%
print("Total_Spending(standard deviation):", df["Total_Spending"].std())
# Out:
# Total_Spending(standard deviation): 11730.63914443037

# %%
print(df["Product_Interactions"].corr(df["Purchase_Frequency"]))
# Out:
# 0.9940111287487514
